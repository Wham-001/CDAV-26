# %% [markdown]
# <a href="https://colab.research.google.com/github/Wham-001/CDAV-26/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# inputs in Python

# %%
name=input("what is your name ")
# Out:
# what is your name Angela

# %%
print(name)
# Out:
# Angela

# %%
name=input("what is your name? ")
food=input("what is your favourite food? ")
sport=input("what is your favourite sport? ")
# Out:
# what is your name? Angela
# what is your favourite food? chicken
# what is your favourite sport? football

# %%
print("hello",name)
print("you like",food)
print("your favourite sport is",sport)
# Out:
# hello Angela
# you like chicken
# your favourite sport is football

# %% [markdown]
# data types

# %%
type("hello")
# Out:
# str

# %%
type(10)
# Out:
# int

# %%
type(223.87)
# Out:
# float

# %%
type(4/7)
# Out:
# float

# %%
x=14
y=34.89
is_raining=True
is_sunny=False

# %%
print(type(x))
print(type(y))
print(type(is_raining))
print(type(is_sunny))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# operators

# %%
print(1+1)
print(10-2)
print(10*2)
print(10/2)
print(5//2)
print(5%2)
print(5**2)
# Out:
# 2
# 8
# 20
# 5.0
# 2
# 1
# 25

# %% [markdown]
# type casting
# #the process of chaging one data type to a compatible data type

# %%
x=10
print(type(x))
# Out:
# <class 'int'>

# %%
x=float(x)
print(type(x))
print(x)
# Out:
# <class 'float'>
# 10.0

# %%
temp=input("what is your body temperature in celsius?" )
temp=float(temp)
#temp=36.5
temp_2=(temp*1.8)+32
print("Your temperature in farenheit is",temp_2)
# Out:
# what is your body temperature in celsius?36.5
# Your temperature in farenheit is 97.7

# %%
x=input("num1 ")
y=input("num2 ")

x_int = int(x)
y_int = int(y)

print("sum:", x_int + y_int)
print("difference:", x_int - y_int)
print("multiplication:", x_int * y_int)
print("division:", x_int / y_int)
print("div 2:", x_int // y_int)
print("modulus:", x_int % y_int)
# Out:
# num1 10
# num2 2
# sum: 12
# difference: 8
# multiplication: 20
# division: 5.0
# div 2: 5
# modulus: 0
