# %% [markdown]
# <a href="https://colab.research.google.com/github/Wham-001/CDAV-26/blob/main/day2afternnoontask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(20>10)
print(10>20)
# Out:
# True
# False

# %%
print(5==5)
# Out:
# True

# %%
print(5!=5)
# Out:
# False

# %%
name=input("name: ")
age=input("age: ")
course=input("course: ")
# Out:
# name: Angela
# age: 19
# course: Data Science

# %%
print("Name:",name)
print("Age:",age)
print("Course:",course)
# Out:
# Name: Angela
# Age: 19
# Course: Data Science

# %%
item_name=input("item name: ")
price=input("price: ")
quantity=input("quantity: ")
price=float(price)
quantity=int(quantity)
print("total:",price*quantity)
# Out:
# item name: Apples
# price: 50
# quantity: 4
# total: 200.0

# %%
YOB=input("year of birth: ")
YOB=int(YOB)
print("Calculated age:",2026-YOB)
# Out:
# year of birth: 2006
# Calculated age: 20

# %%
weight=input("weight: ")
height=input("height: ")
weight=float(weight)
height=float(height)
BMI=(weight/height**2)
print("BMI:",weight/height**2)
# Out:
# weight: 67
# height: 1.56
# BMI: 27.531229454306374
